# %% [markdown]
# # Analyzing the Linear Relaxation

# %%
from _evaluation import (  # the code has been moved to a separate file
    get_sample,
    n,
    samples,
)

# %% [markdown]
# ## Getting a sample solution
#
# The following code will create a random instance and solve
#
# 1. The linear relaxation with `>=2` subtour elimination constraints
# 2. The linear relaxation with `>=1` subtour elimination constraints
# 3. The integer programming problem to get an optimal solution
#
# It will plot the solutions for you to compare and save the results in the `samples` list.
#
# In the plots, the red lines represent fractional edges, i.e., edges with a value between 0 and 1.
# The green lines represent edges where the linear relaxation and the optimal solution agree.
# The title will show the objective value of the solution or the overlap between the linear relaxation and the optimal solution.

# %%
# Run me to get a sample on linear relaxation and integral solution
get_sample(50)
print(f"There are now {len(samples)} samples")
# Out:
# Solving the linear relaxation with k=2
# Set parameter LogToConsole to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 24.04.3 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13650HX, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 51 rows, 1225 columns and 3675 nonzeros (Min)
# Model fingerprint: 0xedd44551
# Model has 1225 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+01, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 5e+01]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 50 rows, 1225 columns, 2450 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.2400000e+02   9.700000e+01   0.000000e+00      0s
#       70    5.5920000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 70 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  5.592000000e+03
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 24.04.3 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13650HX, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 56 rows, 1225 columns and 5401 nonzeros (Min)
# Model has 1225 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+01, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 5e+01]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.5920000e+03   1.000000e+01   0.000000e+00      0s
#        7    5.7855000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 7 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  5.785500000e+03
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 24.04.3 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13650HX, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 59 rows, 1225 columns and 6895 nonzeros (Min)
# Model has 1225 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+01, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 5e+01]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.7855000e+03   6.000000e+00   0.000000e+00      0s
#        5    5.8325000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 5 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  5.832500000e+03
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 24.04.3 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13650HX, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 64 rows, 1225 columns and 8389 nonzeros (Min)
# Model has 1225 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+01, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 5e+01]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.8325000e+03   1.000000e+01   0.000000e+00      0s
#        7    5.8700000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 7 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  5.870000000e+03
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 24.04.3 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13650HX, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 67 rows, 1225 columns and 9231 nonzeros (Min)
# Model has 1225 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+01, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 5e+01]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.8700000e+03   6.000000e+00   0.000000e+00      0s
#        1    5.8745000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  5.874500000e+03
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 24.04.3 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13650HX, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 69 rows, 1225 columns and 9833 nonzeros (Min)
# Model has 1225 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+01, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 5e+01]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.8745000e+03   4.000000e+00   0.000000e+00      0s
#        5    5.8885000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 5 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  5.888500000e+03
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 24.04.3 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13650HX, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 71 rows, 1225 columns and 10505 nonzeros (Min)
# Model has 1225 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+01, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 5e+01]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.8885000e+03   4.000000e+00   0.000000e+00      0s
#        1    5.8900000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  5.890000000e+03
# Solving the integral problem
# Set parameter LogToConsole to value 1
# Set parameter TimeLimit to value 30
# Set parameter LazyConstraints to value 1
# Set parameter MIPGap to value 0.001
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 24.04.3 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13650HX, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 20 logical processors, using up to 20 threads
#
# Non-default parameters:
# TimeLimit  30
# MIPGap  0.001
# LazyConstraints  1
#
# Optimize a model with 51 rows, 1225 columns and 3675 nonzeros (Min)
# Model fingerprint: 0xa94ec33a
# Model has 1225 linear objective coefficients
# Variable types: 0 continuous, 1225 integer (1225 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+01, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 5e+01]
# Presolve time: 0.00s
# Presolved: 51 rows, 1225 columns, 3579 nonzeros
# Variable types: 0 continuous, 1225 integer (1225 binary)
#
# Root relaxation: objective 5.592000e+03, 51 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5592.00000    0    6          - 5592.00000      -     -    0s
# H    0     0                    18909.000000 5592.00000  70.4%     -    0s
# H    0     0                    16992.000000 5592.00000  67.1%     -    0s
# H    0     0                    14385.000000 5592.00000  61.1%     -    0s
# H    0     0                    14344.000000 5592.00000  61.0%     -    0s
#      0     0 5782.00000    0    6 14344.0000 5782.00000  59.7%     -    0s
#      0     0 5802.00000    0   10 14344.0000 5802.00000  59.6%     -    0s
# H    0     0                    13231.000000 5802.00000  56.1%     -    0s
# H    0     0                    5925.0000000 5802.00000  2.08%     -    0s
#      0     0 5890.00000    0   24 5925.00000 5890.00000  0.59%     -    0s
#      0     0 5912.33333    0   35 5925.00000 5912.33333  0.21%     -    0s
#      0     0     cutoff    0      5925.00000 5925.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 1
#
# Explored 1 nodes (121 simplex iterations) in 0.08 seconds (0.05 work units)
# Thread count was 20 (of 20 available processors)
#
# Solution count 6: 5925 13231 14344 ... 18909
#
# Optimal solution found (tolerance 1.00e-03)
# Best objective 5.925000000000e+03, best bound 5.925000000000e+03, gap 0.0000%
#
# User-callback calls 199, time in user-callback 0.02 sec
# Solving the linear relaxation with k=1
# Set parameter LogToConsole to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 24.04.3 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13650HX, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 52 rows, 1225 columns and 4900 nonzeros (Min)
# Model fingerprint: 0x2412329c
# Model has 1225 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e+01, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 6e+03]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 51 rows, 1225 columns, 3675 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.2400000e+02   1.373281e+03   0.000000e+00      0s
#      105    5.9250000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 105 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  5.925000000e+03
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 24.04.3 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-13650HX, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 20 logical processors, using up to 20 threads
#
# Optimize a model with 57 rows, 1225 columns and 6366 nonzeros (Min)
# Model has 1225 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [2e+01, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 6e+03]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.9250000e+03   1.280000e+02   0.000000e+00      0s
#       14    5.9250000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 14 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  5.925000000e+03
# Objective value: 5925.0, Linear relaxation k=2 value: 5890.0, Overlap: 44/50
# There are now 11 samples

# %%
for i, (objective_value, linear_relaxation_value, overlap) in enumerate(samples):
    print(
        f"Sample {i}: Objective value: {objective_value}, Linear relaxation value (>=2): {linear_relaxation_value}, Overlap: {overlap}/{n}"
    )
# Out:
# Sample 0: Objective value: 5670.0, Linear relaxation value (>=2): 5595.5, Overlap: 47/200
